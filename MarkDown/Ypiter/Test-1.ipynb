# %% [markdown]
# ### Test

# %%
import pandas as pd
import numpy as np

# %%
anime = pd.read_csv(r'C:\Users\gatsk\OneDrive\Рабочий стол\Python1-master\MarkDown\Ypiter\anime.csv')
anime.head()

anime_copy = anime.copy()
# Вывод первых 5 элементов списка
anime_copy.head(5)
# вывод последнего элемента списка
anime_copy.tail(1)
# Out:
#        anime_id                              name   genre   type episodes  \
# 12293     26081  Yasuji no Pornorama: Yacchimae!!  Hentai  Movie        1
#
#        rating  members
# 12293    5.46      142

# %%
# Создание и сохранение данных в другой файл csv
anime = pd.read_csv(r'C:\Users\gatsk\OneDrive\Рабочий стол\Python1-master\MarkDown\Ypiter\anime.csv')

anime[:50].to_csv('saved_anime.csv',index=False)
testSave  = pd.read_csv(r"C:\Users\gatsk\OneDrive\Рабочий стол\Python1-master\MarkDown\Ypiter\anime.csv")
testSave[['name','genre','type','episodes']]
# Out:
#                                                     name  \
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                        Under World
# 12291                     Violence Gekiga David no Hoshi
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# ...

# %%
# Создание своего дата фрэйма (таблицы)
soloData = pd.DataFrame([[1,"Max","Gatskan","Nikolaevich"],
                        [2, "Test","MAN", "sHIMBA"],
                        [3, "Test","MAN", "Test"]],
                        index=['MPT','REY','BAY'],
                        columns=["id","name","FIO", "Otch"])
# сохранение нашего DataFrame
soloData.to_csv('MyDataFrame.csv')

myPD = pd.read_csv(r'C:\Users\gatsk\OneDrive\Рабочий стол\Python1-master\MarkDown\Ypiter\anime.csv')
soloData
# Out:
#      id  name      FIO         Otch
# MPT   1   Max  Gatskan  Nikolaevich
# REY   2  Test      MAN       sHIMBA
# BAY   3  Test      MAN         Test

# %%
# Подсчет уникальных значений в DataFrame
anime.nunique()
# Out:
# anime_id    12294
# name        12292
# genre        3264
# type            6
# episodes      187
# rating        598
# members      6706
# dtype: int64

# %%
anime = pd.read_csv(r'C:\Users\gatsk\OneDrive\Рабочий стол\Python1-master\MarkDown\Ypiter\anime.csv')
# вывод колличества уникальных элементов 
len(anime['anime_id'].unique())
# Получение сведений о датафрейме
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
# Вывод статистических сведений о датафрейме
anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
# Подсчёт количества значений
# type - это столбец по которому идет подсчет
anime.type.value_counts()
# Out:
# TV         3787
# OVA        3311
# Movie      2348
# Special    1676
# ONA         659
# Music       488
# Name: type, dtype: int64

# %%
# Создание списка или объекта Series на основе значений столбца
testM = anime['genre'].tolist()
# testM = anime['genre']
testM
# Out:
# ['Drama, Romance, School, Supernatural',
#  'Action, Adventure, Drama, Fantasy, Magic, Military, Shounen',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Sci-Fi, Thriller',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Comedy, Drama, School, Shounen, Sports',
#  'Action, Adventure, Shounen, Super Power',
#  'Drama, Military, Sci-Fi, Space',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Drama, Fantasy, Romance, Slice of Life, Supernatural',
#  'Drama, School, Shounen',
#  'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#  'Action, Drama, Mecha, Military, Sci-Fi, Super Power',
#  'Comedy, Drama, School, Shounen, Sports',
#  'Adventure, Drama, Supernatural',
#  'Drama, Music, Romance, School, Shounen',
#  'Adventure, Fantasy, Historical, Mystery, Seinen, Slice of Life, Supernatural',
#  'Fantasy, Slice of Life',
# ...

# %%
# Создание нового датафрейма из подмножества столбцов
# Это может пригодиться в том случае, если требуется сохранить в новом датафрейме несколько столбцов огромного датафрейма, но при этом не хочется выписывать имена столбцов, которые нужно удалить
nowCol = anime[['name','episodes']]
nowCol
# Out:
#                                                     name episodes
# 0                                         Kimi no Na wa.        1
# 1                       Fullmetal Alchemist: Brotherhood       64
# 2                                               Gintama°       51
# 3                                            Steins;Gate       24
# 4                                          Gintama&#039;       51
# ...                                                  ...      ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami        1
# 12290                                        Under World        1
# 12291                     Violence Gekiga David no Hoshi        4
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...        1
# 12293                   Yasuji no Pornorama: Yacchimae!!        1
#
# [12294 rows x 2 columns]

# %%
# Удаление заданных столбцов
# Этот приём может оказаться полезным в том случае, если из датафрейма нужно удалить лишь несколько столбцов.
# Если удалять нужно много столбцов, то эта задача может оказаться довольно-таки утомительной, 
# поэтому тут я предпочитаю пользоваться возможностью, описанной в предыдущем разделе.

dropDF = testSave.drop(['anime_id', 'genre', 'members'], axis=1)
dropDF
# Out:
#                                                     name   type episodes  \
# 0                                         Kimi no Na wa.  Movie        1
# 1                       Fullmetal Alchemist: Brotherhood     TV       64
# 2                                               Gintama°     TV       51
# 3                                            Steins;Gate     TV       24
# 4                                          Gintama&#039;     TV       51
# ...                                                  ...    ...      ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami    OVA        1
# 12290                                        Under World    OVA        1
# 12291                     Violence Gekiga David no Hoshi    OVA        4
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...    OVA        1
# 12293                   Yasuji no Pornorama: Yacchimae!!  Movie        1
#
#        rating
# 0        9.37
# 1        9.26
# 2        9.25
# 3        9.17
# ...

# %%
# В pandas axis = 0 относится к горизонтальной оси или строкам, а axis = 1 относится к вертикальной оси или столбцам.
df = pd.DataFrame([[1,'Bob', 8000],
                  [2,'Sally', 9000],
                  [3,'Scott', 20]], columns=['id','name', 'power level'])
df.append(df.mean(axis=0), ignore_index=True)
# Out:
# C:\Users\gatsk\AppData\Local\Temp\ipykernel_11036\3756533213.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.append(df.mean(axis=0), ignore_index=True)
# C:\Users\gatsk\AppData\Local\Temp\ipykernel_11036\3756533213.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df.mean(axis=0), ignore_index=True)
#     id   name  power level
# 0  1.0    Bob  8000.000000
# 1  2.0  Sally  9000.000000
# 2  3.0  Scott    20.000000
# 3  2.0    NaN  5673.333333

# %%
# Комбинирование датафреймов
# Эта методика применима в ситуациях, когда имеются два датафрейма с одинаковыми столбцами, которые нужно скомбинировать.
# В данном примере мы сначала разделяем датафрейм на две части, а потом снова объединяем эти части:
df1 = anime[0:2]
df2 = anime[2:4]
pd.concat([df1, df2])
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572

# %%
# Фильтрация при помощи loc
soloData.loc[['BAY']]
# Фильтрация при помощи iloc по id c 1 по 3 элемент
soloData.iloc[0:3]
# Out:
#      id  name      FIO         Otch
# MPT   1   Max  Gatskan  Nikolaevich
# REY   2  Test      MAN       sHIMBA
# BAY   3  Test      MAN         Test

# %%
# Получение строк по заданным значениям столбцов
# Для получения строк датафрейма в ситуации, когда имеется список значений столбцов, можно воспользоваться следующей командой:
anime[anime['type'].isin(['TV', 'Movie'])]

# Если нас интересует единственное значение — можно воспользоваться такой конструкцией:
anime[anime['type'] == 'TV']
# Out:
#        anime_id                                               name  \
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# 5         32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# ...         ...                                                ...
# 11104     34522                          Wake Up, Girls! Shin Shou
# 11106     34467                             Yami Shibai 4th Season
# 11107     32615                                        Youjo Senki
# 11110     34284  Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou
# 11111     34445       Yuuki Yuuna wa Yuusha de Aru: Yuusha no Shou
#
#                                                    genre type episodes  \
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64
# ...

# %%
# Фильтрация по значению
# Из датафреймов можно выбирать строки, соответствующие заданному условию. 
# Обратите внимание на то, что при использовании этого метода сохраняются существующие индексные значения.
anime[anime['rating'] >=9.5]
# Out:
#        anime_id                                     name            genre  \
# 9595      23005                         Mogura no Motoro    Slice of Life
# 10400     30120              Spoon-hime no Swing Kitchen  Adventure, Kids
# 10464     33662  Taka no Tsume 8: Yoshida-kun no X-Files   Comedy, Parody
#
#         type episodes  rating  members
# 9595   Movie        1     9.5       62
# 10400     TV  Unknown     9.6       47
# 10464  Movie        1    10.0       13

# %%
# Сортировка
# Для сортировки датафреймов по значениям столбцов можно воспользоваться функцией df.sort_values:
anime.sort_values('rating', ascending=False).tail(5)
# Out:
#        anime_id                                               name  \
# 12274     34492  Nuki Doki! Tenshi to Akuma no Sakusei Battle -...
# 12279     34491                       Sagurare Otome The Animation
# 12280     34312                                       Saimin Class
# 12282     34388                    Shikkoku no Shaga The Animation
# 12285     34399                                   Taimanin Asagi 3
#
#                               genre type episodes  rating  members
# 12274                        Hentai  OVA  Unknown     NaN      392
# 12279                        Hentai  OVA        1     NaN       79
# 12280                        Hentai  OVA  Unknown     NaN      240
# 12282                        Hentai  OVA  Unknown     NaN      195
# 12285  Demons, Hentai, Supernatural  OVA  Unknown     NaN      485

# %%
# Агрегирование
# Функция df.groupby и подсчёт количества записей
# Вот как подсчитать количество записей с различными значениями в столбцах:

Grouptype =  anime.groupby('type').count()
Grouptype
# Out:
#          anime_id  name  genre  episodes  rating  members
# type
# Movie        2348  2348   2306      2348    2297     2348
# Music         488   488    488       488     488      488
# ONA           659   659    655       659     652      659
# OVA          3311  3311   3310      3311    3285     3311
# Special      1676  1676   1674      1676    1671     1676
# TV           3787  3787   3777      3787    3671     3787

# %%
# Поиск
Grouptype.loc[['Movie']]
# Out:
#        anime_id  name  genre  episodes  rating  members
# type
# Movie      2348  2348   2306      2348    2297     2348

# %%
anime.groupby(["type"]).agg({
  "rating": "sum",
  "episodes": "count",
  "name": "first"
}).reset_index()
# Out:
#       type    rating  episodes                              name
# 0    Movie  14512.58      2348                    Kimi no Na wa.
# 1    Music   2727.43       488                           Shelter
# 2      ONA   3679.43       659                      Eve no Jikan
# 3      OVA  20942.60      3311              Ginga Eiyuu Densetsu
# 4  Special  10900.77      1676      Mushishi Special: Hihamukage
# 5       TV  25338.34      3787  Fullmetal Alchemist: Brotherhood

# %%
# tmp_df = anime.copy()
# tmp_df.sort_values('user_id', ascending=True, inplace=True)
# tmp_df = tmp_df[tmp_df.user_id < 10] 
# tmp_df = tmp_df[tmp_df.anime_id < 30]
# tmp_df = tmp_df[tmp_df.rating != -1]
# pd.pivot_table(tmp_df, values='rating', index=['user_id'], columns=['anime_id'], aggfunc=np.sum, fill_value=0)
